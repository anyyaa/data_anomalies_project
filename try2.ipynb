# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
#дополнение графика ани с названиями вместо url адресов
import matplotlib.pyplot as plt
top_pages = df['url'].value_counts().head(10)
top_pages.index = df.drop_duplicates('url').set_index('url')['title'].loc[top_pages.index]

plt.figure(figsize=(10, 6))
top_pages.sort_values().plot(kind='barh', color='green')
plt.title('Топ-10 самых популярных страниц', fontsize=16)
plt.xlabel('Количество событий', fontsize=14)
plt.ylabel('Заголовок страницы', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
